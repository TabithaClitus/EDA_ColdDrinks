# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df = pd.read_csv("regression_datasets_large.xlsx - Cold_Drink_Sales.csv")
X = df[["Temperature_C"]]   
y = df["Sales"]             
model = LinearRegression()
model.fit(X, y)
slope = model.coef_[0]
intercept = model.intercept_
print(f"Regression Equation: Sales = {slope:.2f} * Temperature + {intercept:.2f}")
sales40 = model.predict([[40]])[0]
print(f"Predicted Sales: {sales40:.2f}")
# Out:
# Regression Equation: Sales = 1.33 * Temperature + 525.05
# Predicted Sales at 40°C: 578.23
# d:\AI WORKFORCE\cold drinks\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y, c="blue")
plt.plot(X, model.predict(X), c="red")
plt.scatter(40, sales40, c="green", marker="x", s=200)
plt.show()
