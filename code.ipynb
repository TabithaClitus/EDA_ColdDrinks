# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
df = pd.read_csv("regression_datasets_large.xlsx - Cold_Drink_Sales.csv")
X = df[["Temperature_C"]]   #feature matrix
y = df["Sales"]               #target
model = LinearRegression()
model.fit(X, y)
sales40 = model.predict([[40]])[0]
print(f"Predicted Sales at 40°C: {sales40:.2f}")
y_predict = model.predict(X)
residuals = y - y_predict
plt.figure(figsize=(8,5))
plt.scatter(df["Temperature_C"], residuals)
plt.axhline(0, linestyle='--',color="red")
plt.xlabel("Temperature (°C)")
plt.ylabel("Residuals")
plt.title("Residuals vs Temperature")
plt.show()
# Out:
# d:\AI WORKFORCE\cold drinks\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Sales at 40°C: 578.23

# %% [markdown]
# USING HISTOGRAM

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
df = pd.read_csv("regression_datasets_large.xlsx - Cold_Drink_Sales.csv")
X = df[["Temperature_C"]]
y = df["Sales"]
model = LinearRegression()
model.fit(X, y)
sales40 = model.predict([[40]])[0]
print(f"Predicted Sales at 40°C: {sales40:.2f}")
y_predict = model.predict(X)
residuals = y - y_predict
plt.figure(figsize=(6,4))
plt.hist(residuals, bins=20, edgecolor="black")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residuals")
plt.show()
# Out:
# d:\AI WORKFORCE\cold drinks\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Sales at 40°C: 578.23
